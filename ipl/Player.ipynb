# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("Player.csv")

# %%
df
# Out:
#      Player_Id      Player_Name        DOB Batting_Hand       Bowling_Skill  \
# 0            1       SC Ganguly   8-Jul-72    Left_Hand    Right-arm medium
# 1            2      BB McCullum  27-Sep-81   Right_Hand    Right-arm medium
# 2            3       RT Ponting  19-Dec-74   Right_Hand    Right-arm medium
# 3            4        DJ Hussey  15-Jul-77   Right_Hand  Right-arm offbreak
# 4            5  Mohammad Hafeez  17-Oct-80   Right_Hand  Right-arm offbreak
# ..         ...              ...        ...          ...                 ...
# 518        519      Subroto Das        NaN          NaN                 NaN
# 519        520     K Srinivasan        NaN          NaN                 NaN
# 520        521        VK Sharma        NaN          NaN                 NaN
# 521        523      AV Wankhade  14-Mar-92   Right_Hand                 NaN
# 522        524      B Aparajith   8-Jul-94   Right_Hand  Right-arm offbreak
#
#          Country  Is_Umpire  Unnamed: 7
# ...

# %%
umpire=df[df["Is_Umpire"]==1]

# %%
umpire.head(2) #these are umpire in that list we have taken just two so won't take more space
# Out:
#      Player_Id Player_Name  DOB Batting_Hand Bowling_Skill   Country  \
# 469        470   Asad Rauf  NaN          NaN           NaN  Pakistan
# 470        471   MR Benson  NaN          NaN           NaN   England
#
#      Is_Umpire  Unnamed: 7
# 469          1         1.0
# 470          1         2.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 523 entries, 0 to 522
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Player_Id      523 non-null    int64
#  1   Player_Name    523 non-null    object
#  2   DOB            471 non-null    object
#  3   Batting_Hand   471 non-null    object
#  4   Bowling_Skill  427 non-null    object
#  5   Country        523 non-null    object
#  6   Is_Umpire      523 non-null    int64
#  7   Unnamed: 7     12 non-null     float64
# dtypes: float64(1), int64(2), object(5)
# memory usage: 32.8+ KB

# %%
playervscountry=df['Country'].value_counts()
playervscountry
# Out:
# India           291
# Australia        78
# South Africa     44
# New Zealand      26
# Sri Lanka        22
# West Indies      20
# England          18
# Pakistan         15
# Bangladesh        5
# Zimbabwea         3
# Netherlands       1
# Name: Country, dtype: int64

# %%
country=df['Country'].value_counts().keys()

# %%
country
# Out:
# Index(['India', 'Australia', 'South Africa', 'New Zealand', 'Sri Lanka',
#        'West Indies', 'England', 'Pakistan', 'Bangladesh', 'Zimbabwea',
#        'Netherlands'],
#       dtype='object')

# %%
df.Country.unique()
# Out:
# array(['India', 'New Zealand', 'Australia', 'Pakistan', 'South Africa',
#        'Sri Lanka', 'West Indies', 'Zimbabwea', 'England', 'Bangladesh',
#        'Netherlands'], dtype=object)

# %%
plt.figure(figsize=(20,5))
plt.bar(country,playervscountry)
plt.ylabel("no of player",loc='top')
plt.xlabel('country name',loc='right')
# Out:
# Text(1, 0, 'country name')

# %%
df['DOB']=pd.to_datetime(df['DOB'])

# %%
pakistani=df[df['Country']=="Pakistan"]

# %%
pakistani
# Out:
#      Player_Id      Player_Name        DOB Batting_Hand  \
# 4            5  Mohammad Hafeez 1980-10-17   Right_Hand
# 68          69     Kamran Akmal 1982-01-13   Right_Hand
# 69          70    Shahid Afridi 1980-03-01   Right_Hand
# 85          86     Shoaib Malik 1982-02-01   Right_Hand
# 101        102    Sohail Tanvir 1984-12-12    Left_Hand
# 102        103      Salman Butt 1984-10-07    Left_Hand
# 104        105         Umar Gul 1984-04-14   Right_Hand
# 112        113    Misbah-ul-Haq 1974-05-28   Right_Hand
# 116        117    Mohammad Asif 1982-12-20    Left_Hand
# 140        141      Younis Khan 1977-11-29   Right_Hand
# 143        144    Shoaib Akhtar 1975-08-13   Right_Hand
# 178        179     Shoaib Ahmed 1990-08-17   Right_Hand
# 320        321    Azhar Mahmood 1975-02-28   Right_Hand
# 469        470        Asad Rauf        NaT          NaN
# 471        472        Aleem Dar        NaT          NaN
#
#              Bowling_Skill   Country  Is_Umpire  Unnamed: 7
# ...

# %%
indian=df[df['Country']=='India']

# %%
lefti_indian=indian[indian['Batting_Hand']=='Left_Hand']

# %%
len(lefti_indian) #total 61 batsman are lefti in indian
# Out:
# 61

# %%
lefti_indian.head(2)
# Out:
#     Player_Id Player_Name        DOB Batting_Hand           Bowling_Skill  \
# 0           1  SC Ganguly 1972-07-08    Left_Hand        Right-arm medium
# 15         16    SB Joshi 2070-06-06    Left_Hand  Slow left-arm orthodox
#
#    Country  Is_Umpire  Unnamed: 7
# 0    India          0         NaN
# 15   India          0         NaN

# %%
plt.figure(figsize=(10,12))
myexplode=np.repeat(0,len(country))  #this is in int data type so 0.2 means 0
myexplode=myexplode.astype(float) #so changed to float type
myexplode[0]=0.2

plt.pie(playervscountry,labels=country,explode=myexplode,shadow=True)
plt.legend(title='country',ncol=3,loc='upper right')
plt.show()

# %%
df=df.sort_values(by=['Player_Name'],ascending=True) #arranging player by ascending order by name

# %%
df
# Out:
#      Player_Id     Player_Name        DOB Batting_Hand  \
# 324        325  A Ashish Reddy 1991-02-24   Right_Hand
# 334        335      A Chandila 1983-12-05   Right_Hand
# 127        128        A Chopra 1977-09-19   Right_Hand
# 154        155      A Flintoff 1977-12-06   Right_Hand
# 123        124        A Kumble 2070-10-17   Right_Hand
# ..         ...             ...        ...          ...
# 113        114     YV Takawale 1984-11-05   Right_Hand
# 169        170   Yashpal Singh 1981-11-27   Right_Hand
# 140        141     Younis Khan 1977-11-29   Right_Hand
# 26          27    Yuvraj Singh 1981-12-12    Left_Hand
# 14          15          Z Khan 1978-10-07   Right_Hand
#
#               Bowling_Skill   Country  Is_Umpire  Unnamed: 7
# 324        Right-arm medium     India          0         NaN
# 334      Right-arm offbreak     India          0         NaN
# 127      Right-arm offbreak     India          0         NaN
# ...

# %%
vname=[]
for name in df['Player_Name']:
    if name.startswith('V'):
        vname.append(name)
vname
# Out:
# ['V Kohli',
#  'V Pratap Singh',
#  'V Sehwag',
#  'V Shankar',
#  'VA Kulkarni',
#  'VH Zol',
#  'VK Sharma',
#  'VR Aaron',
#  'VRV Singh',
#  'VS Malik',
#  'VS Yeligati',
#  'VVS Laxman',
#  'VY Mahesh']

# %%
df[df.Player_Name.isin(vname)] #these are player whose name start with V
# Out:
#      Player_Id     Player_Name        DOB Batting_Hand          Bowling_Skill  \
# 7            8         V Kohli 1988-11-05   Right_Hand       Right-arm medium
# 325        326  V Pratap Singh 1992-05-03   Right_Hand       Right-arm medium
# 40          41        V Sehwag 1978-10-20   Right_Hand     Right-arm offbreak
# 454        455       V Shankar 1991-01-26   Right_Hand       Right-arm medium
# 495        496     VA Kulkarni        NaT          NaN                    NaN
# 383        384          VH Zol 1994-11-23    Left_Hand     Right-arm offbreak
# 520        521       VK Sharma        NaT          NaN                    NaN
# 295        296        VR Aaron 1989-10-29   Right_Hand         Right-arm fast
# 77          78       VRV Singh 1984-09-17   Right_Hand  Right-arm medium-fast
# 242        243        VS Malik 1983-05-09   Right_Hand       Right-arm medium
# 149        150     VS Yeligati 1985-04-23   Right_Hand     Right-arm offbreak
# ...

# %%
Australia=df[df['Country']=='Australia']
Australia
# Out:
#      Player_Id  Player_Name        DOB Batting_Hand          Bowling_Skill  \
# 55          56    A Symonds 1975-06-09   Right_Hand     Right-arm offbreak
# 429        430      A Zampa 1992-03-31   Right_Hand        Legbreak googly
# 12          13    AA Noffke 1977-04-30   Right_Hand  Right-arm fast-medium
# 197        198  AB McDonald 1981-06-05   Right_Hand  Right-arm fast-medium
# 288        289  AC Blizzard 1984-06-27    Left_Hand        Left-arm medium
# ..         ...          ...        ...          ...                    ...
# 237        238      SW Tait 1983-02-22   Right_Hand         Right-arm fast
# 271        272     TD Paine 1984-12-08   Right_Hand       Right-arm medium
# 416        417      TM Head 1993-12-29    Left_Hand     Right-arm offbreak
# 284        285      TR Birt 1981-12-09    Left_Hand       Right-arm medium
# 425        426   UT Khawaja 1986-12-18    Left_Hand       Right-arm medium
#
#        Country  Is_Umpire  Unnamed: 7
# ...

# %%
df.loc[0]
# Out:
# Player_Id                          1
# Player_Name               SC Ganguly
# DOB              1972-07-08 00:00:00
# Batting_Hand               Left_Hand
# Bowling_Skill       Right-arm medium
# Country                        India
# Is_Umpire                          0
# Unnamed: 7                       NaN
# Name: 0, dtype: object
